# %%
import numpy as np
import pandas as pd

df = pd.read_csv('Cleaned-P&P data.csv')
df.head()
# Out:
#   class                                               desc     inc_num  \
# 0     P  good afternoon , \r\n\r\n this customer charge...  INC0809260
# 1     R  please remove delivery pass removed attached s...  INC0808628
# 2     O  set ( acustrss ) 1 account holder receive stat...  INC0807303
# 3     R  please delivery pass removed attached staff ac...  INC0807253
# 4     P  customer : d4957244 \r\n website : jd williams...  INC0806836
#
#                                            short_des
# 0                                           y2684992
# 1  delivery pass needs removing on staff accounts...
# 2                                           g7121564
# 3  delivery pass needs removing on staff accounts...
# 4                customer being charged for delivery

# %%
blanks = []  # start with an empty list`

for i,c,d,inc,sd in df.itertuples():  # iterate over the DataFrame
        if c == 'O' or c=='E':         # test 'review' for whitespace
            blanks.append(i)     # add matching index numbers to the list
df.drop(blanks, inplace=True)

# %%
df["desc"] = df["short_des"] + '. ' + df["desc"]
len(df)
# Out:
# 244

# %% [markdown]
# #### Pre-processing

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
tfidf = TfidfVectorizer(max_df=0.95, min_df=2)

# %%
dtm = tfidf.fit_transform(df['desc'])

# %% [markdown]
# #### NMF

# %%
from sklearn.decomposition import NMF

# %%
nmf_model = NMF(n_components=2,random_state=42)

# %%
# This can take awhile, we're dealing with a large amount of documents!
nmf_model.fit(dtm)
# Out:
# NMF(alpha=0.0, beta_loss='frobenius', init=None, l1_ratio=0.0, max_iter=200,
#   n_components=2, random_state=42, shuffle=False, solver='cd', tol=0.0001,
#   verbose=0)

# %%
len(tfidf.get_feature_names())
# Out:
# 375

# %%
import random
for i in range(374):
    print(tfidf.get_feature_names()[i])
# Out:
# 01
# 02
# 03
# 04
# 05
# 06
# 07
# 08
# 09
# 10
# 10th
# 11
# 12
# 12th
# 139
# 14
# 14th
# 15th
# 16
# 161236
# 17
# 17th
# 18
# 19
# 1st
# 2017
# 2018
# 2019
# 2020
# 20th
# 22
# 23
# 236123
# 23rd
# 24
# 24th
# 25
# 27
# 27th
# 28
# 28th
# 29
# 29th
# 30th
# 3506
# 3521
# 3544
# 3553
# 3594
# 3603
# 3620
# 3643
# 3651
# 3657
# 3806
# 3829
# 384a
# 3913
# 3rd
# 44
# 4th
# 50
# 8256
# 95
# 99
# 995
# 9th
# able
# account
# accountno
# accounts
# accountwith
# activate
# activated
# activating
# active
# add
# added
# adding
# advance
# advise
# advisor
# affected
# after
# afternoon
# ahmed
# all
# ambrose
# amount
# angela
# anita
# annual
# applicable
# application
# applied
# apply
# april
# arron
# assist
# attached
# august
# based
# be
# being
# bought
# brands
# brown
# browser
# but
# buying
# called
# can
# cancel
# cancellation
# cancelled
# care
# catherine
# cc
# charge
# charged
# charges
# charging
# check
# chris
# citrix
# claire
# clothing
# co
# code
# coles
# com
# connolly
# contact
# contactno
# country
# cust
# customer
# customerid
# customerno
# customers
# date
# day
# dba
# dec
# del
# deliver
# deliveries
# description
# despite
# details
# diagnosis
# digital
# edwards
# eligible
# error
# errormessage
# even
# everytime
# expiry
# ext
# fashion
# fault
# feb
# february
# fg
# fix
# following
# footwear
# for
# form
# free
# from
# future
# getting
# glen
# global
# good
# got
# has
# having
# he
# hello
# help
# hi
# hill
# hussain
# id
# if
# in
# incidents
# incurring
# instead
# is
# issue
# issues
# it
# item
# itemno
# jacamo
# jacqueline
# january
# jd
# jdwilliams
# jean
# joanne
# july
# june
# karen
# keeps
# key
# kind
# kindly
# l450
# line
# liv
# longer
# look
# louise
# mainframe
# manager
# managers
# manchester
# manually
# many
# march
# marisota
# message
# monika
# month
# months
# mr
# mrs
# ms
# na
# name
# nbrown
# need
# needs
# new
# nixon
# no
# not
# notification
# nov
# november
# number
# of
# offer
# oliviaorwa
# on
# one
# option
# order
# ordered
# ordering
# orderno
# orders
# our
# paid
# pass
# passes
# pay
# pence
# pens
# people
# peter
# place
# placed
# places
# placing
# please
# pm
# pnt
# posting
# pound
# pounds
# proactive
# product
# pss
# purchase
# purchased
# purchasing
# raising
# re
# rebecca
# reception
# rectify
# refund
# refunded
# regards
# remove
# removed
# removing
# report
# reported
# req
# request
# requests
# resolve
# restarted
# retail
# retailer
# roger
# rv
# rv139
# rv139fg
# rv139fn
# sandra
# sefali
# september
# service
# session
# shamim
# she
# shipping
# shop
# short
# showing
# simple
# simply
# simplybe
# spreadsheet
# staff
# standard
# stewart
# still
# sub
# subject
# subscribed
# subscription
# subscriptionbut
# subscriptions
# supplement
# supra
# susan
# taken
# taking
# team
# thank
# thanks
# the
# they
# this
# though
# till
# time
# to
# today
# took
# tried
# trying
# uk
# unable
# unlimited
# use
# user
# valid
# wants
# web
# website
# websites
# williams
# wilson
# with
# work
# working
# works
# world
# wrigley
# wrongly
# www
# year
# yearbut
# yearly

# %%
len(nmf_model.components_)
# Out:
# 2

# %%
single_topic = nmf_model.components_[0]
single_topic.argsort()
# Out:
# array([172, 179, 180, 184, 188, 191, 192, 193, 194, 196, 197, 198, 199,
#        201, 178, 202, 204, 205, 206, 207, 211, 217, 218, 222, 224, 226,
#        227, 228, 229, 203, 177, 174, 173, 134, 136, 137, 138, 140, 141,
#        367, 143, 147, 148, 149, 150, 152, 154, 155, 156, 157, 158, 159,
#        160, 161, 162, 163, 165, 365, 168, 170, 363, 344, 230, 231, 232,
#        233, 293, 294, 302, 304, 307, 308, 309, 312, 313, 314, 315, 316,
#        318, 319, 320, 350, 349, 324, 325, 326, 329, 330, 331, 332, 334,
#        347, 340, 341, 343, 353, 133, 354, 287, 234, 361, 360, 240, 243,
#        245, 246, 247, 359, 250, 251, 254, 255, 358, 258, 261, 262, 263,
#        264, 266, 267, 268, 269, 355, 273, 274, 275, 279, 281, 288, 132,
#        345,  21,  64,  65,  66,  67, 372, 371,  27,  71,  72,  63,  26,
#         78,  80,  82,  83,  20,  88,  89,  17,  93,  24,  94,  61,  58,
#         35,  36,  37,  38,  33,  39,  40,  42,  43, 130,  44,  47,  49,
#         50,  51,  53,  54,  55,  57,  28,  46,  13,  34, 110, 119, 118,
#        116,  10,  96, 109, 108, 107, 104, 120, 102, 101, 128, 100, 121,
#        369,  98,  97,  73, 306,  92, 200, 146, 239,  56,  52,  48, 186,
#        253, 362,  81, 335,  45,  14, 303, 213, 189, 299, 282, 311, 103,
#        151, 122,   9, 175, 115, 214, 248, 164,  29, 348,  60,   3,  87,
#         85, 185,  31, 283, 285, 126,  59, 301,  62, 221, 257,  19, 106,
#        167, 209, 105, 300,  12, 284, 131, 327, 336, 357,   2,   4, 220,
#         32, 124, 323, 190,   1,  86, 370,  25, 210,  69, 216, 305, 366,
#         18, 289,   7, 123, 356,  79,  74,  84, 176, 187, 286, 238, 317,
#        215, 181, 117, 328,   6,  30,  16, 272,  15, 271, 144, 195,  76,
#        297, 265,  23, 182, 351, 244,   5, 235, 364, 252, 114, 352, 208,
#        127,   8, 242,  75,  41,  11, 135, 298, 373, 276, 241, 296, 280,
#         95, 346, 112, 139,  22, 277, 219, 111,  77, 153, 125, 368, 212,
#        337, 129,  90, 342, 223, 310, 225, 278,   0, 145, 321, 169, 113,
#        166, 236, 260, 183,  91, 374,  68, 171, 290, 338, 339, 270, 291,
#         99, 256, 249, 237, 295, 142, 333, 292, 259,  70, 322], dtype=int64)

# %%
# Word least representative of this topic
single_topic[363]
# Out:
# 0.0

# %%
top_word_indices = single_topic.argsort()[-10:]

# %%
for index in top_word_indices:
    print(tfidf.get_feature_names()[index])
# Out:
# orders
# on
# needs
# req
# dba
# supra
# removing
# pass
# accounts
# staff

# %%
for index,topic in enumerate(nmf_model.components_):
    print(f'THE TOP 15 WORDS FOR TOPIC #{index}')
    print([tfidf.get_feature_names()[i] for i in topic.argsort()[-15:]])
    print('\n')
# Out:
# THE TOP 15 WORDS FOR TOPIC #0
# ['thank', 'thanks', 'please', 'removed', 'attached', 'orders', 'on', 'needs', 'req', 'dba', 'supra', 'removing', 'pass', 'accounts', 'staff']
#
#
# THE TOP 15 WORDS FOR TOPIC #1
# ['website', 'account', 'being', 'issue', 'free', 'order', 'pass', 'getting', 'not', 'working', 'number', 'for', 'charged', 'subscription', 'customer']

# %%
dtm
# Out:
# <244x375 sparse matrix of type '<class 'numpy.float64'>'
# 	with 4454 stored elements in Compressed Sparse Row format>

# %%
dtm.shape
# Out:
# (244, 375)

# %%
topic_results = nmf_model.transform(dtm)

# %%
topic_results.shape
# Out:
# (244, 2)

# %%
topic_results[11]
# Out:
# array([0.04586123, 0.06781565])

# %%
df['Topic'] = topic_results.argmax(axis=1)

# %%
df.head(10)
# Out:
#    class                                               desc     inc_num  \
# 0      P  y2684992. y2684992. good afternoon , \r\n\r\n ...  INC0809260
# 1      R  delivery pass needs removing on staff accounts...  INC0808628
# 3      R  delivery pass needs removing on staff accounts...  INC0807253
# 4      P  customer being charged for delivery. customer ...  INC0806836
# 5      P  website/web shop issues. website/web shop issu...  INC0805994
# 6      P  delivery passes. delivery passes. hi \r\n\r\n ...  INC0805875
# 7      R  delivery pass needs removing on staff account ...  INC0803134
# 8      R  delivery pass needs removing on staff accounts...  INC0798911
# 9      P  customer being charged for delivery. customer ...  INC0793541
# 10     R  delivery pass needs removing on orders supra d...  INC0793103
#
#                                             short_des  Topic
# 0                                            y2684992      1
# 1   delivery pass needs removing on staff accounts...      0
# 3   delivery pass needs removing on staff accounts...      0
# 4                 customer being charged for delivery      1
# 5                             website/web shop issues      1
# 6                                     delivery passes      0
# 7   delivery pass needs removing on staff account ...      0
# 8   delivery pass needs removing on staff accounts...      0
# 9                 customer being charged for delivery      1
# 10  delivery pass needs removing on orders supra d...      0

# %%
tpdict = {1:'Add Delivery pass' , 0:'Remove Delivery Pass'}
df['Topic Label'] = df['Topic'].map(tpdict)
cldict = {'P':1 , 'R':0}
df['Class Label'] = df['class'].map(cldict)

# %%
df
# Out:
#     class                                               desc     inc_num  \
# 0       P  y2684992. y2684992. good afternoon , \r\n\r\n ...  INC0809260
# 1       R  delivery pass needs removing on staff accounts...  INC0808628
# 3       R  delivery pass needs removing on staff accounts...  INC0807253
# 4       P  customer being charged for delivery. customer ...  INC0806836
# 5       P  website/web shop issues. website/web shop issu...  INC0805994
# 6       P  delivery passes. delivery passes. hi \r\n\r\n ...  INC0805875
# 7       R  delivery pass needs removing on staff account ...  INC0803134
# 8       R  delivery pass needs removing on staff accounts...  INC0798911
# 9       P  customer being charged for delivery. customer ...  INC0793541
# 10      R  delivery pass needs removing on orders supra d...  INC0793103
# 11      P  delivery subscription not working. delivery su...  INC0791461
# 12      R  annual delivery pass cancelled.. annual delive...  INC0791140
# 13      R  delivery pass needs removing on staff account ...  INC0791135
# 14      P  delivery subscription not working for orders. ...  INC0790422
# 16      P  getting charged for delivery. getting charged ...  INC0790128
# 17      P  delivery subscription is not working. delivery...  INC0789893
# 18      P  issue with delivery subscription. issue with d...  INC0789809
# 19      R  delivery pass needs removing on staff accounts...  INC0789262
# 20      P  delivery subasciption issue.. delivery subasci...  INC0788860
# 21      R  delivery pass needs removing on staff accounts...  INC0787814
# 22      P  website/web shop issues. website/web shop issu...  INC0787080
# 23      R  delivery pass needs removing on staff accounts...  INC0786284
# 24      P  x8426166 - delivery pass. x8426166 - delivery ...  INC0785823
# 25      P  s1905074 - delivery subscription. s1905074 - d...  INC0784605
# 26      R  delivery pass needs removing on staff accounts...  INC0783884
# 27      P  customer getting charged for delivery after de...  INC0781648
# 28      P  haven't received the delivery pass. haven't re...  INC0780929
# 29      P  i4505902. i4505902. i4505902 \r\n \r\n good af...  INC0779381
# 30      R  delivery pass needs removing from staff accoun...  INC0779242
# 31      P  customer charged even after adding delivery su...  INC0776815
# ..    ...                                                ...         ...
# 222     R  delivery pass needs removing from staff accoun...  INC0594204
# 223     R  delivery pass needs removing from staff accoun...  INC0587203
# 224     R  delivery pass needs removing on staff accounts...  INC0584945
# 225     P  annual delivery pass not working. annual deliv...  INC0584110
# 226     R  delivery pass needs removing on staff accounts...  INC0582212
# 227     R  delivery pass needs removing on staff accounts...  INC0579360
# 228     P  being charged for shipping wrongly. being char...  INC0578971
# 229     R  remove delivery pass. remove delivery pass. pl...  INC0578947
# 230     P  customer unable to apply delivery pass.. custo...  INC0577874
# 231     R  delivery pass needs removing on staff accounts...  INC0577679
# 232     R  delivery pass needs removing on staff accounts...  INC0572706
# 233     R  delivery pass needs removing on staff accounts...  INC0567503
# 234     R  annual delivery pass needs removing on marisot...  INC0566569
# 235     R  delivery pass needs removing on staff accounts...  INC0561586
# 236     R  delivery pass needs removing on staff accounts...  INC0558886
# 237     R  delivery pass needs removing on staff accounts...  INC0554282
# 238     R  delivery pass needs removing on staff accounts...  INC0551436
# 239     R  delivery pass needs removing on staff accounts...  INC0549333
# 240     R  delivery pass needs removing from staff accoun...  INC0544192
# 241     R  delivery pass needs removing on staff accounts...  INC0537440
# 242     R  delivery pass needs removing on  staff account...  INC0534280
# 243     R  delivery pass needs removing on staff accounts...  INC0532119
# 244     R  e0079528 keith ingle. e0079528 keith ingle. ca...  INC0529468
# 245     R  annual delivery pass being charged on staff ac...  INC0528972
# 246     R  delivery pass needs removing on staff accounts...  INC0524983
# 248     R  delivery passes needs removing from staff acco...  INC0511076
# 249     R  delivery pass needs removing on staff accounts...  INC0505435
# 250     P  mrs jacqueline ralston          t6409483. mrs ...  INC0503771
# 251     R  delivery pass needs removing on staff accounts...  INC0496369
# 252     R  priority 1 - delivery pass needs removing on s...  INC0493290
#
#                                              short_des  Topic  \
# 0                                             y2684992      1
# 1    delivery pass needs removing on staff accounts...      0
# 3    delivery pass needs removing on staff accounts...      0
# 4                  customer being charged for delivery      1
# 5                              website/web shop issues      1
# 6                                      delivery passes      0
# 7    delivery pass needs removing on staff account ...      0
# 8    delivery pass needs removing on staff accounts...      0
# 9                  customer being charged for delivery      1
# 10   delivery pass needs removing on orders supra d...      0
# 11                   delivery subscription not working      1
# 12                     annual delivery pass cancelled.      1
# 13   delivery pass needs removing on staff account ...      0
# 14        delivery subscription not working for orders      1
# 16                        getting charged for delivery      1
# 17                delivery subscription is not working      1
# 18                    issue with delivery subscription      1
# 19   delivery pass needs removing on staff accounts...      0
# 20                        delivery subasciption issue.      1
# 21   delivery pass needs removing on staff accounts...      0
# 22                             website/web shop issues      1
# 23   delivery pass needs removing on staff accounts...      0
# 24                            x8426166 - delivery pass      1
# 25                    s1905074 - delivery subscription      1
# 26   delivery pass needs removing on staff accounts...      0
# 27   customer getting charged for delivery after de...      1
# 28                  haven't received the delivery pass      1
# 29                                            i4505902      1
# 30   delivery pass needs removing from staff accoun...      0
# 31   customer charged even after adding delivery su...      1
# ..                                                 ...    ...
# 222  delivery pass needs removing from staff accoun...      0
# 223  delivery pass needs removing from staff accoun...      0
# 224  delivery pass needs removing on staff accounts...      0
# 225                   annual delivery pass not working      1
# 226  delivery pass needs removing on staff accounts...      0
# 227  delivery pass needs removing on staff accounts...      0
# 228                 being charged for shipping wrongly      1
# 229                               remove delivery pass      1
# 230            customer unable to apply delivery pass.      1
# 231  delivery pass needs removing on staff accounts...      0
# 232  delivery pass needs removing on staff accounts...      0
# 233  delivery pass needs removing on staff accounts...      0
# 234  annual delivery pass needs removing on marisot...      0
# 235  delivery pass needs removing on staff accounts...      0
# 236  delivery pass needs removing on staff accounts...      0
# 237  delivery pass needs removing on staff accounts...      0
# 238  delivery pass needs removing on staff accounts...      0
# 239  delivery pass needs removing on staff accounts...      0
# 240  delivery pass needs removing from staff accoun...      0
# 241  delivery pass needs removing on staff accounts...      0
# 242  delivery pass needs removing on  staff account...      0
# 243  delivery pass needs removing on staff accounts...      0
# 244                               e0079528 keith ingle      1
# 245  annual delivery pass being charged on staff ac...      0
# 246  delivery pass needs removing on staff accounts...      0
# 248  delivery passes needs removing from staff acco...      0
# 249  delivery pass needs removing on staff accounts...      0
# 250           mrs jacqueline ralston          t6409483      1
# 251  delivery pass needs removing on staff accounts...      0
# 252  priority 1 - delivery pass needs removing on s...      0
#
#               Topic Label  Class Label
# 0       Add Delivery pass            1
# 1    Remove Delivery Pass            0
# 3    Remove Delivery Pass            0
# 4       Add Delivery pass            1
# 5       Add Delivery pass            1
# 6    Remove Delivery Pass            1
# 7    Remove Delivery Pass            0
# 8    Remove Delivery Pass            0
# 9       Add Delivery pass            1
# 10   Remove Delivery Pass            0
# 11      Add Delivery pass            1
# 12      Add Delivery pass            0
# 13   Remove Delivery Pass            0
# 14      Add Delivery pass            1
# 16      Add Delivery pass            1
# 17      Add Delivery pass            1
# 18      Add Delivery pass            1
# 19   Remove Delivery Pass            0
# 20      Add Delivery pass            1
# 21   Remove Delivery Pass            0
# 22      Add Delivery pass            1
# 23   Remove Delivery Pass            0
# 24      Add Delivery pass            1
# 25      Add Delivery pass            1
# 26   Remove Delivery Pass            0
# 27      Add Delivery pass            1
# 28      Add Delivery pass            1
# 29      Add Delivery pass            1
# 30   Remove Delivery Pass            0
# 31      Add Delivery pass            1
# ..                    ...          ...
# 222  Remove Delivery Pass            0
# 223  Remove Delivery Pass            0
# 224  Remove Delivery Pass            0
# 225     Add Delivery pass            1
# 226  Remove Delivery Pass            0
# 227  Remove Delivery Pass            0
# 228     Add Delivery pass            1
# 229     Add Delivery pass            0
# 230     Add Delivery pass            1
# 231  Remove Delivery Pass            0
# 232  Remove Delivery Pass            0
# 233  Remove Delivery Pass            0
# 234  Remove Delivery Pass            0
# 235  Remove Delivery Pass            0
# 236  Remove Delivery Pass            0
# 237  Remove Delivery Pass            0
# 238  Remove Delivery Pass            0
# 239  Remove Delivery Pass            0
# 240  Remove Delivery Pass            0
# 241  Remove Delivery Pass            0
# 242  Remove Delivery Pass            0
# 243  Remove Delivery Pass            0
# 244     Add Delivery pass            0
# 245  Remove Delivery Pass            0
# 246  Remove Delivery Pass            0
# 248  Remove Delivery Pass            0
# 249  Remove Delivery Pass            0
# 250     Add Delivery pass            1
# 251  Remove Delivery Pass            0
# 252  Remove Delivery Pass            0
#
# [244 rows x 7 columns]

# %%
for n,c,d,i,s,t,l,cl in df.itertuples():
    if t!=cl:
        print(i, c, n )
# Out:
# INC0805875 P 6
# INC0791140 R 12
# INC0770868 R 41
# INC0699015 P 115
# INC0685865 R 126
# INC0667087 P 154
# INC0647183 R 177
# INC0630640 R 186
# INC0628447 P 187
# INC0628144 R 188
# INC0625595 R 191
# INC0624883 R 192
# INC0624810 R 193
# INC0622781 R 197
# INC0622283 R 199
# INC0622277 R 200
# INC0622190 R 202
# INC0612636 P 208
# INC0597850 R 217
# INC0578947 R 229
# INC0529468 R 244

# %%
print(df.loc[[197]])
# Out:
#     class                                               desc     inc_num  \
# 197     R  delivery pass cancellation. delivery pass canc...  INC0622781
#
#                       short_des  Topic        Topic Label  Class Label
# 197  delivery pass cancellation      1  Add Delivery pass            0

# %%
df['desc'][197]
# Out:
# 'delivery pass cancellation. delivery pass cancellation. s1259052 - please delivery subscription service removed?thanks !'
